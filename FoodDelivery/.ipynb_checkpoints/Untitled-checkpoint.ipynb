# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
train=pd.read_excel("train.xlsx")
test=pd.read_excel("test.xlsx")

# %%
train.head()
# Out:
#   Restaurant                             Location  \
# 0    ID_6321  FTI College, Law College Road, Pune
# 1    ID_2882                 Sector 3, Marathalli
# 2    ID_1595                       Mumbai Central
# 3    ID_5929                      Sector 1, Noida
# 4    ID_6123   Rmz Centennial, I Gate, Whitefield
#
#                                  Cuisines Average_Cost Minimum_Order Rating  \
# 0  Fast Food, Rolls, Burger, Salad, Wraps         ₹200           ₹50    3.5
# 1                     Ice Cream, Desserts         ₹100           ₹50    3.5
# 2         Italian, Street Food, Fast Food         ₹150           ₹50    3.6
# 3          Mughlai, North Indian, Chinese         ₹250           ₹99    3.7
# 4                         Cafe, Beverages         ₹200           ₹99    3.2
#
#   Votes Reviews Delivery_Time
# 0    12       4    30 minutes
# 1    11       4    30 minutes
# 2    99      30    65 minutes
# 3   176      95    30 minutes
# 4   521     235    65 minutes

# %%
test.head()
# Out:
#   Restaurant                                    Location  \
# 0    ID_2842  Mico Layout, Stage 2, BTM Layout,Bangalore
# 1     ID_730  Mico Layout, Stage 2, BTM Layout,Bangalore
# 2    ID_4620                             Sector 1, Noida
# 3    ID_5470                  Babarpur, New Delhi, Delhi
# 4    ID_3249                             Sector 1, Noida
#
#                                             Cuisines Average_Cost  \
# 0                    North Indian, Chinese, Assamese         ₹350
# 1                                     Biryani, Kebab         ₹100
# 2                                          Fast Food         ₹100
# 3  Mithai, North Indian, Chinese, Fast Food, Sout...         ₹200
# 4                                 Chinese, Fast Food         ₹150
#
#   Minimum_Order Rating Votes Reviews
# 0           ₹50    4.2   361     225
# 1           ₹50    NEW     -       -
# 2           ₹50    3.6    36      16
# 3           ₹50    3.6    66      33
# ...

# %%
#df=train.append(test,ignore_index=True)
#df.head()
df=pd.concat([train,test],ignore_index=True)
df.head()
# Out:
#   Restaurant                             Location  \
# 0    ID_6321  FTI College, Law College Road, Pune
# 1    ID_2882                 Sector 3, Marathalli
# 2    ID_1595                       Mumbai Central
# 3    ID_5929                      Sector 1, Noida
# 4    ID_6123   Rmz Centennial, I Gate, Whitefield
#
#                                  Cuisines Average_Cost Minimum_Order Rating  \
# 0  Fast Food, Rolls, Burger, Salad, Wraps         ₹200           ₹50    3.5
# 1                     Ice Cream, Desserts         ₹100           ₹50    3.5
# 2         Italian, Street Food, Fast Food         ₹150           ₹50    3.6
# 3          Mughlai, North Indian, Chinese         ₹250           ₹99    3.7
# 4                         Cafe, Beverages         ₹200           ₹99    3.2
#
#   Votes Reviews Delivery_Time
# 0    12       4    30 minutes
# 1    11       4    30 minutes
# 2    99      30    65 minutes
# 3   176      95    30 minutes
# 4   521     235    65 minutes

# %%
train.shape,test.shape,df.shape
# Out:
# ((11094, 9), (2774, 8), (13868, 9))

# %%
for col in df.columns:
    print(col+" "+str(df[col].nunique()))
    print(df[col].value_counts())
# Out:
# Restaurant 8661
# ID_5538    26
# ID_7184    25
# ID_2483    24
# ID_4654    23
# ID_1209    23
#            ..
# ID_5489     1
# ID_1693     1
# ID_1439     1
# ID_7869     1
# ID_6876     1
# Name: Restaurant, Length: 8661, dtype: int64
# Location 35
# Mico Layout, Stage 2, BTM Layout,Bangalore          1158
# D-Block, Sector 63, Noida                           1027
# Sector 1, Noida                                      990
# FTI College, Law College Road, Pune                  734
# Delhi University-GTB Nagar                           699
# Sector 14, Noida                                     630
# Laxman Vihar Industrial Area, Sector 3A, Gurgoan     611
# Delhi Administration Flats, Timarpur                 602
# Rmz Centennial, I Gate, Whitefield                   585
# Mumbai Central                                       578
# MG Road, Pune                                        509
# Delhi High Court, India Gate                         504
# ...

# %%
 df=df.loc[df['Average_Cost']!='for',:]
 for item in ["Opening Soon","Temporarily Closed"]:
    df=df.loc[df["Rating"]!= item ,:]
 df.shape
# Out:
# (13851, 9)

# %%
df["Average_Cost"]=df.Average_Cost.str.replace('₹','')
df["Average_Cost"]=df.Average_Cost.str.replace(',','')

# %%
df["Average_Cost"]=pd.to_numeric(df["Average_Cost"])

# %%
df.head()
# Out:
#   Restaurant                             Location  \
# 0    ID_6321  FTI College, Law College Road, Pune
# 1    ID_2882                 Sector 3, Marathalli
# 2    ID_1595                       Mumbai Central
# 3    ID_5929                      Sector 1, Noida
# 4    ID_6123   Rmz Centennial, I Gate, Whitefield
#
#                                  Cuisines  Average_Cost Minimum_Order Rating  \
# 0  Fast Food, Rolls, Burger, Salad, Wraps           200           ₹50    3.5
# 1                     Ice Cream, Desserts           100           ₹50    3.5
# 2         Italian, Street Food, Fast Food           150           ₹50    3.6
# 3          Mughlai, North Indian, Chinese           250           ₹99    3.7
# 4                         Cafe, Beverages           200           ₹99    3.2
#
#   Votes Reviews Delivery_Time
# 0    12       4    30 minutes
# 1    11       4    30 minutes
# 2    99      30    65 minutes
# 3   176      95    30 minutes
# 4   521     235    65 minutes

# %%
df["Minimum_Order"]=df.Minimum_Order.str.replace('₹','')
df["Minimum_Order"]=df.Minimum_Order.str.replace(',','')

# %%
df["Minimum_Order"]=df["Minimum_Order"].astype('int')

# %%
df.head()
# Out:
#   Restaurant                             Location  \
# 0    ID_6321  FTI College, Law College Road, Pune
# 1    ID_2882                 Sector 3, Marathalli
# 2    ID_1595                       Mumbai Central
# 3    ID_5929                      Sector 1, Noida
# 4    ID_6123   Rmz Centennial, I Gate, Whitefield
#
#                                  Cuisines  Average_Cost  Minimum_Order Rating  \
# 0  Fast Food, Rolls, Burger, Salad, Wraps           200             50    3.5
# 1                     Ice Cream, Desserts           100             50    3.5
# 2         Italian, Street Food, Fast Food           150             50    3.6
# 3          Mughlai, North Indian, Chinese           250             99    3.7
# 4                         Cafe, Beverages           200             99    3.2
#
#   Votes Reviews Delivery_Time
# 0    12       4    30 minutes
# 1    11       4    30 minutes
# 2    99      30    65 minutes
# 3   176      95    30 minutes
# 4   521     235    65 minutes

# %%
df.dtypes
# Out:
# Restaurant       object
# Location         object
# Cuisines         object
# Average_Cost      int64
# Minimum_Order     int32
# Rating           object
# Votes            object
# Reviews          object
# Delivery_Time    object
# dtype: object

# %%
df["Rating"].value_counts()
# Out:
# -      1496
# 3.7    1081
# 3.6    1069
# 3.5    1015
# 3.8     983
# 3.9     965
# NEW     957
# 3.4     903
# 3.3     828
# 4.0     755
# 3.2     640
# 4.1     574
# 3.1     531
# 3.0     367
# 4.2     342
# 4.3     299
# 2.9     256
# 2.8     198
# 4.4     171
# 2.7      98
# 4.5      96
# 2.6      51
# 4.6      48
# 4.7      42
# 2.5      33
# 2.4      18
# 4.8      16
# 2.3       8
# 4.9       8
# 2.1       2
# 2.2       1
# Name: Rating, dtype: int64

# %%
df["Restaurant_type"]=np.where(df.Rating=="-",2,np.where(df.Rating=='NEW',1,0))

# %%
df["Restaurant_type"].value_counts()
# Out:
# 0    11398
# 2     1496
# 1      957
# Name: Restaurant_type, dtype: int64

# %%
df["Rating"]=df["Rating"].replace({"NEW":-999,"-":-999})

# %%
df["Rating"]=df["Rating"].astype(float)

# %%
df["Votes"]=df["Votes"].replace({"-":-999})
df["Reviews"]=df["Reviews"].replace({"-":-999})

# %%
df["Votes"]=df["Votes"].astype(float)
df["Reviews"]=df["Reviews"].astype(float)

# %%
df.dtypes
# Out:
# Restaurant          object
# Location            object
# Cuisines            object
# Average_Cost         int64
# Minimum_Order        int32
# Rating             float64
# Votes              float64
# Reviews            float64
# Delivery_Time       object
# Restaurant_type      int32
# dtype: object

# %%
df.head()
# Out:
#   Restaurant                             Location  \
# 0    ID_6321  FTI College, Law College Road, Pune
# 1    ID_2882                 Sector 3, Marathalli
# 2    ID_1595                       Mumbai Central
# 3    ID_5929                      Sector 1, Noida
# 4    ID_6123   Rmz Centennial, I Gate, Whitefield
#
#                                  Cuisines  Average_Cost  Minimum_Order  \
# 0  Fast Food, Rolls, Burger, Salad, Wraps           200             50
# 1                     Ice Cream, Desserts           100             50
# 2         Italian, Street Food, Fast Food           150             50
# 3          Mughlai, North Indian, Chinese           250             99
# 4                         Cafe, Beverages           200             99
#
#    Rating  Votes  Reviews Delivery_Time  Restaurant_type
# 0     3.5   12.0      4.0    30 minutes                0
# 1     3.5   11.0      4.0    30 minutes                0
# 2     3.6   99.0     30.0    65 minutes                0
# ...

# %%
df['votes_review_rating'] = df.Votes*df.Reviews*df.Rating

# %%
df['Delivery_Time']=df['Delivery_Time'].str.replace(' minutes','')
df['Delivery_Time']=pd.to_numeric(df['Delivery_Time'])

# %%
df['City']=df.Location.str.rpartition(',')[2]
df['Locality']=df.Location.str.rpartition(',')[0]

# %%
df.head()
# Out:
#   Restaurant                             Location  \
# 0    ID_6321  FTI College, Law College Road, Pune
# 1    ID_2882                 Sector 3, Marathalli
# 2    ID_1595                       Mumbai Central
# 3    ID_5929                      Sector 1, Noida
# 4    ID_6123   Rmz Centennial, I Gate, Whitefield
#
#                                  Cuisines  Average_Cost  Minimum_Order  \
# 0  Fast Food, Rolls, Burger, Salad, Wraps           200             50
# 1                     Ice Cream, Desserts           100             50
# 2         Italian, Street Food, Fast Food           150             50
# 3          Mughlai, North Indian, Chinese           250             99
# 4                         Cafe, Beverages           200             99
#
#    Rating  Votes  Reviews  Delivery_Time  Restaurant_type  \
# 0     3.5   12.0      4.0           30.0                0
# 1     3.5   11.0      4.0           30.0                0
# ...

# %%
df.Locality.value_counts()
# Out:
#                                            2427
# Mico Layout, Stage 2, BTM Layout           1158
# D-Block, Sector 63                         1026
# Sector 1                                    987
# FTI College, Law College Road               734
# Sector 14                                   630
# Laxman Vihar Industrial Area, Sector 3A     611
# Delhi Administration Flats                  602
# Rmz Centennial, I Gate                      584
# MG Road                                     506
# Delhi High Court                            504
# Nathan Road, Mangaldas Road                 474
# Sandhurst Road                              462
# Sector 3                                    443
# Yerawada, Pune                              379
# Dockyard Road                               362
# Babarpur, New Delhi                         336
# Sector 63A                                  321
# Moulali                                     173
# Chandni Chowk                               156
# ...

# %%
df.Locality[df.City.str.contains('Delhi University-GTB Nagar')]='Delhi University-GTB Nagar'
df.Locality[df.City.str.contains('Mumbai Central')]='Mumbai Central'
df.Locality[df.City.str.contains('Majestic')]='Majestic'
df.Locality[df.City.str.contains('Delhi Cantt.')]='Delhi Cantt'
df.Locality[df.City.str.contains('Pune University')]='Pune University'
#df['Locality'] = data['Locality'].str.strip()
#df['Locality'] = data['Locality'].str.lower()
# Out:
# C:\Users\mishr\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\mishr\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\mishr\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.Locality=df.Locality.str.strip()
df.Locality=df.Locality.str.lower()
df.Locality
# Out:
# 0           fti college, law college road
# 1                                sector 3
# 2                          mumbai central
# 3                                sector 1
# 4                  rmz centennial, i gate
#                        ...
# 13863          delhi university-gtb nagar
# 13864    mico layout, stage 2, btm layout
# 13865           noorkhan bazaar, malakpet
# 13866                  d-block, sector 63
# 13867                       dockyard road
# Name: Locality, Length: 13851, dtype: object

# %%
df.City[df.City.str.contains('Delhi University-GTB Nagar')]='Delhi'
df.City[df.City.str.contains('Mumbai CST Area')]='Mumbai'
df.City[df.City.str.contains('Mumbai Central')]='Mumbai'
df.City[df.City.str.contains('India Gate')]='Delhi'
df.City[df.City.str.contains('Delhi Cantt.')]='Delhi'
df.City[df.City.str.contains('Maharashtra')]='Pune'
df.City[df.City.str.contains('Pune University')]='Pune'
df.City[df.City.str.contains('Gurgoan')]='Gurgaon'
df.City[df.City.str.contains('Electronic City')]='Bangalore'

# data.City[data.City.str.contains('Whitefield')]='Bangalore'
# data.City[data.City.str.contains('Marathalli')]='Bangalore'

df['City'] = df['City'].str.strip()
df['City'] = df['City'].str.lower()
del df['Location']
# Out:
# C:\Users\mishr\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\mishr\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\mishr\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.head()
# Out:
#   Restaurant                                Cuisines  Average_Cost  \
# 0    ID_6321  Fast Food, Rolls, Burger, Salad, Wraps           200
# 1    ID_2882                     Ice Cream, Desserts           100
# 2    ID_1595         Italian, Street Food, Fast Food           150
# 3    ID_5929          Mughlai, North Indian, Chinese           250
# 4    ID_6123                         Cafe, Beverages           200
#
#    Minimum_Order  Rating  Votes  Reviews  Delivery_Time  Restaurant_type  \
# 0             50     3.5   12.0      4.0           30.0                0
# 1             50     3.5   11.0      4.0           30.0                0
# 2             50     3.6   99.0     30.0           65.0                0
# 3             99     3.7  176.0     95.0           30.0                0
# 4             99     3.2  521.0    235.0           65.0                0
#
#    votes_review_rating        City                       Locality
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant                0
# Cuisines                  0
# Average_Cost              0
# Minimum_Order             0
# Rating                    0
# Votes                     0
# Reviews                   0
# Delivery_Time          2772
# Restaurant_type           0
# votes_review_rating       0
# City                      0
# Locality                  0
# dtype: int64

# %%
print(df.shape)
# Out:
# (13851, 12)

# %%
df['Cuisines'] = df['Cuisines'].str.lower()
df['Cuisines'] = df['Cuisines'].str.replace(' ','')

# %%
df.head()
# Out:
#   Restaurant                           Cuisines  Average_Cost  Minimum_Order  \
# 0    ID_6321  fastfood,rolls,burger,salad,wraps           200             50
# 1    ID_2882                  icecream,desserts           100             50
# 2    ID_1595        italian,streetfood,fastfood           150             50
# 3    ID_5929        mughlai,northindian,chinese           250             99
# 4    ID_6123                     cafe,beverages           200             99
#
#    Rating  Votes  Reviews  Delivery_Time  Restaurant_type  \
# 0     3.5   12.0      4.0           30.0                0
# 1     3.5   11.0      4.0           30.0                0
# 2     3.6   99.0     30.0           65.0                0
# 3     3.7  176.0     95.0           30.0                0
# 4     3.2  521.0    235.0           65.0                0
#
#    votes_review_rating        City                       Locality
# 0                168.0        pune  fti college, law college road
# ...

# %%
cuisines=df['Cuisines'][0].split(',')

# %%
df.Cuisines.unique()[2]
# Out:
# 'italian,streetfood,fastfood'

# %%
temp=df.groupby(['Restaurant','City']).mean()

# %%
temp.loc[('ID_0','delhi'),'Average_Cost']
# Out:
# 150.0

# %%
temp['ID_0']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ID_0'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-81-4522547d5d7d> in <module>
# ----> 1 temp['ID_0']
#
# ...
